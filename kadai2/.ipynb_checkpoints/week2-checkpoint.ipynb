# %%
# ライブラリのインストール
import numpy as np
import pandas as pd

# 癌のデータをロード
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# 説明変数X（特徴量）と目的変数y（正解ラベル）を作成
X = data.data
y = data.target

# データの確認
#pd.DataFrame(X, columns = data.feature_names)
#pd.DataFrame(y, columns = ['target']) # data.target_names

# %%
# 例として今回はロジスティック回帰というモデルを使用。オブジェクトを作成。
from sklearn import linear_model
clf = linear_model.LogisticRegression(max_iter=10000)

# ホールドアウト法による、データの分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size = 0.5,    # 訓練データの割合を指定
    shuffle = True,      # シャッフルするかどうかを指定、デフォルトはTrue
    random_state = 1234  # シャッフル時の乱数を固定
)

# 学習
clf.fit(X_train, y_train)

# テストデータで精度を測る
clf.score(X_test, y_test)
# Out:
# 0.9508771929824561

# %%
# クラスの中身を見てみる
print('訓練データ')
print(np.unique(y_train, return_counts=True))
print(f'{np.unique(y_train)[0]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[0]*100, 2)}%')
print(f'{np.unique(y_train)[1]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[1]*100, 2)}%')
print('==================================')
print('テストデータ')
print(np.unique(y_test,  return_counts=True))
print(f'{np.unique(y_test)[0]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[0]*100, 2)}%')
print(f'{np.unique(y_test)[1]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[1]*100, 2)}%')

print('==================================')
# もともとどうだったのか？
print('母集団')
print(np.unique(y, return_counts=True))
print(f'{np.unique(y)[0]}の割合：{round((np.unique(y, return_counts=True)[1]/y.size)[0]*100, 2)}%')
print(f'{np.unique(y)[1]}の割合：{round((np.unique(y, return_counts=True)[1]/y.size)[1]*100, 2)}%')
# Out:
# 訓練データ
# (array([0, 1]), array([109, 175]))
# 0の割合：38.38%
# 1の割合：61.62%
# ...
# テストデータ
# (array([0, 1]), array([103, 182]))
# 0の割合：36.14%
# 1の割合：63.86%
# ...
# 母集団
# (array([0, 1]), array([212, 357]))
# 0の割合：37.26%
# 1の割合：62.74%

# %%
# データを訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size = 0.95, 
    random_state = 1234
)

# 学習
clf.fit(X_train, y_train)

# テストデータで精度を測る
clf.score(X_test, y_test)

# クラスの中身を見てみる
print('訓練データ')
print(np.unique(y_train, return_counts=True))
print(f'{np.unique(y_train)[0]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[0]*100, 2)}%')
print(f'{np.unique(y_train)[1]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[1]*100, 2)}%')

print('テストデータ')
print(np.unique(y_test,  return_counts=True))
print(f'{np.unique(y_test)[0]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[0]*100, 2)}%')
print(f'{np.unique(y_test)[1]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[1]*100, 2)}%')
# Out:
# 訓練データ
# (array([0, 1]), array([ 6, 22]))
# 0の割合：21.43%
# 1の割合：78.57%
# テストデータ
# (array([0, 1]), array([206, 335]))
# 0の割合：38.08%
# 1の割合：61.92%

# %%
#層別サンプリングを行うことで母集団の分布を維持する必要がある
# データを訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size = 0.95, 
    random_state = 1234, 
    stratify = y  # 層化させたい対象を指定
)

# 学習
clf.fit(X_train, y_train)

# テストデータで精度を測る
clf.score(X_test, y_test)

# クラスの中身を見てみる
print('訓練データ')
print(np.unique(y_train, return_counts=True))
print(f'{np.unique(y_train)[0]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[0]*100, 2)}%')
print(f'{np.unique(y_train)[1]}の割合：{round((np.unique(y_train, return_counts=True)[1]/y_train.size)[1]*100, 2)}%')
print('==================================')
print('テストデータ')
print(np.unique(y_test,  return_counts=True))
print(f'{np.unique(y_test)[0]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[0]*100, 2)}%')
print(f'{np.unique(y_test)[1]}の割合：{round((np.unique(y_test, return_counts=True)[1]/y_test.size)[1]*100, 2)}%')
# Out:
# 訓練データ
# (array([0, 1]), array([10, 18]))
# 0の割合：35.71%
# 1の割合：64.29%
# ...
# テストデータ
# (array([0, 1]), array([202, 339]))
# 0の割合：37.34%
# 1の割合：62.66%

# %%
# ライブラリのインストール
import numpy as np

# 癌のデータをロード
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# 説明変数と目的変数（正解ラベル）を作成
X = data.data
y = data.target

# ロジスティック回帰のオブジェクトを作成
from sklearn import linear_model
clf = linear_model.LogisticRegression(max_iter=10000)

# 交差検証法による、データの分割
from sklearn.model_selection import cross_val_score
scores = cross_val_score(
    estimator = clf,
    X = X,
    y = y,
    cv = 10,
    scoring = 'accuracy',
    n_jobs = -1
)

print('k分割目(1~10)の正解率: \n%s' % scores)

# 正解率の平均と標準偏差を出力
print('正解率：%.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# k分割目(1~10)の正解率:
# [0.98245614 0.9122807  0.92982456 0.94736842 0.98245614 0.98245614
#  0.92982456 0.94736842 0.96491228 0.96428571]
# 正解率：0.954 +/- 0.024

# %%
# 上記と同じ
import numpy as np

from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

X = data.data
y = data.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    train_size=0.8,
    test_size=0.2,
    random_state=1234
)

from sklearn import linear_model
clf = linear_model.LogisticRegression(max_iter=10000)

clf.fit(X_train, y_train)

clf.score(X_test, y_test)

y_pred = clf.predict(X_test)

# 混同行列の定義
conf_mat = np.zeros([2, 2])

#自作した場合
# 真の値が行、予測値が列となる行列を作成
for true_label, est_label in zip(y_test, y_pred):
    conf_mat[true_label, est_label] += 1
    
print(conf_mat)
# Out:
# [[39.  6.]
#  [ 0. 69.]]

# %%
import pandas as pd
df = pd.DataFrame(conf_mat,
                  columns = ['pred 0', 'pred 1'],
                  index = ['true 0', 'true 1']
                 )

print(df)
# Out:
#         pred 0  pred 1
# true 0    39.0     6.0
# true 1     0.0    69.0

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# もう一度Accuracyを表示
accuracy_score(y_test, y_pred)
# Out:
# 0.9473684210526315

# %%
# 混同行列を表示
cmat = confusion_matrix(y_test, y_pred)
cmat
# Out:
# array([[39,  6],
#        [ 0, 69]])

# %%
TP = cmat[0, 0] # True Positive
FN = cmat[0, 1] # False Negative
FP = cmat[1, 0] # False Positive
TN = cmat[1, 1] # True Negative

# %%
# データ読み込み
pima_train = pd.read_csv('data/pima_tr.csv') #200*9
pima_test = pd.read_csv('data/pima_te.csv') #332*9

# 結合
group_data = pd.concat([pima_train, pima_test], ignore_index=True) #532*9

# 1列目の削除
del group_data['Unnamed: 0']

# 最初の6行を可視化
group_data.shape
# Out:
# (332, 8)

# %%
# ライブラリの読み込み
import seaborn as sns

# 散布図
sns.pairplot(group_data, hue='type', diag_kind='kde')

# hueを指定するとデータごとに色分けしてくれる
# diag_kind='kde' より、対角線のグラフの種類をヒストグラムからカーネル密度推定に変更

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# trainデータとtestデータに分ける
X = preprocessing.scale(group_data[['npreg', 'glu', 'bp', 'skin', 'bmi', 'ped', 'age']])
y = group_data.type
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size=0.7, stratify = y)

# trainデータに対してkを1から100まで動かし、それぞれに対して交差検証を行う
neighbors = list(range(1, 100))
cv_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors = k)
    scores = cross_val_score(
        knn,
        X_train,
        y_train,
        cv = 10,
        scoring = 'accuracy',
        n_jobs = -1
    )
    cv_scores.append(np.mean(scores))
    
# 結果の可視化
import matplotlib.pyplot as plt
# %matplotlib inline

MSE = [1 - x for x in cv_scores]

optimal_k = neighbors[MSE.index(min(MSE))]
print('The optimal number of k is %d' % optimal_k)

fig, ax = plt.subplots(figsize = (10, 6))
ax.plot(neighbors, MSE)
ax.set_xlabel('Number of Neighbors K')
ax.set_ylabel('Misclassification Error')
# Out:
# The optimal number of k is 13
# Text(0, 0.5, 'Misclassification Error')

# %% [markdown]
# ## 授業内課題1

# %%
import pandas as pd
from sklearn import preprocessing
pima_train = pd.read_csv('data/pima_tr.csv',encoding='UTF-8')
pima_test = pd.read_csv('data/pima_te.csv',encoding='UTF-8')

group_data = pd.concat([pima_train, pima_test], ignore_index=True)
del group_data['Unnamed: 0']
X = preprocessing.scale(group_data[['npreg','glu','bp','skin','bmi','ped','age']])

# %% [markdown]
# ## 授業内課題2

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
pima_train = pd.read_csv('data/pima_tr.csv',encoding='UTF-8')
pima_test = pd.read_csv('data/pima_te.csv',encoding='UTF-8')

group_data = pd.concat([pima_train, pima_test], ignore_index=True)
del group_data['Unnamed: 0']

X = preprocessing.scale(group_data[['npreg','glu','bp','skin','bmi','ped','age']])
y = group_data.type

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size=0.7, stratify=y)

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_train)
cmat = confusion_matrix(y_train, y_pred, labels=['Yes', 'No'])
TP, FN = cmat[0, 0], cmat[0, 1]
print('訓練データに対するTrue Positive Rate:',TP/(TP+FN))

y_pred = knn.predict(X_test)
cmat = confusion_matrix(y_test, y_pred, labels=['Yes', 'No'])
TP, FN = cmat[0, 0], cmat[0, 1]
print('テストデータに対するTrue Positive Rate:',TP/(TP+FN))
# Out:
# 訓練データに対するTrue Positive Rate: 0.75
# テストデータに対するTrue Positive Rate: 0.48484848484848486

# %% [markdown]
# ## レポート課題2

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
# %matplotlib inline
pima_train = pd.read_csv('data/pima_tr.csv',encoding='UTF-8')
pima_test = pd.read_csv('data/pima_te.csv',encoding='UTF-8')

group_data = pd.concat([pima_train, pima_test], ignore_index=True)
del group_data['Unnamed: 0']

X = preprocessing.scale(group_data[['npreg','glu','bp','skin','bmi','ped','age']])
y = group_data.type

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size=0.8, stratify=y)

neighbors = list(range(1, 100))
cv_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors = k)
    scores = cross_val_score(
        knn,
        X_train,
        y_train,
        cv = 10,
        scoring = 'accuracy',
        n_jobs = -1
    )
    cv_scores.append(np.mean(scores))

MSE = [1 - x for x in cv_scores]

optimal_k = neighbors[MSE.index(min(MSE))]
print('The optimal number of k is %d' % optimal_k)

fig, ax = plt.subplots(figsize = (10, 6))
ax.plot(neighbors, MSE)
ax.set_xlabel('Number of Neighbors K')
ax.set_ylabel('Misclassification Error')

knn = KNeighborsClassifier(n_neighbors = optimal_k)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
cmat = confusion_matrix(y_test, y_pred, labels=['Yes', 'No'])
TP, FN = cmat[0, 0], cmat[0, 1]
print('テストデータに対するTrue Positive Rate:',TP/(TP+FN))

print('テストデータに対するAccuracy Score:',accuracy_score(y_test, y_pred))
# Out:
# The optimal number of k is 33
# テストデータに対するTrue Positive Rate: 0.5454545454545454
# テストデータに対するAccuracy Score: 0.835820895522388
